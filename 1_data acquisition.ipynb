# %% [markdown]
# ## This notebook contains the process of data acquisition from three data sources:
# 1. American Community Survey (ACS) 5-Year Data (2009-2018)
#
# 2. AARP.org Livability Index
#
# 3. Census Mapping Files: TIGER/Line Shapefiles

# %%
import io
import requests
import json
from pathlib import Path
import pandas as pd
import numpy as np
import geopandas as gpd

from pandas import DataFrame
from shapely.geometry import Point
from IPython.display import GeoJSON

# %% [markdown]
# # Read median gross rent from US Census data

# %%
API_KEY = '8e8e73ee55d6949e46bd4f555c948d27a1337aa4'

# %%
def get_census_data(variable, state_id, county_id):
    with requests.session() as session:
        params = {
            'get': variable,
            'for': 'block group:*',
            'in': f'state:{state_id} county:{county_id}',
            'key': API_KEY
        }
        url = f'https://api.census.gov/data/2018/acs/acs5'
        response = session.get(url, params=params)
        try:
            response.raise_for_status()
        except Exception as e:
            raise Exception(f'Failed to query {url} due to: {response.text}') from e
        result = response.json()
        df = DataFrame(result[1:], columns=result[0])
    return df

get_census_data('B25058_001E', '34', '001')
# Out:
#     B25058_001E state county   tract block group
# 0          1188    34    001  012402           2
# 1           985    34    001  010900           3
# 2          1365    34    001  011500           2
# 3    -666666666    34    001  011500           3
# 4           909    34    001  012801           1
# ..          ...   ...    ...     ...         ...
# 179  -666666666    34    001  013301           2
# 180        1128    34    001  013302           2
# 181        1632    34    001  013500           2
# 182  -666666666    34    001  990000           0
# 183         929    34    001  010900           1
#
# [184 rows x 5 columns]

# %% [markdown]
# # Read AARP livabiilty data

# %%
def merge_properties_and_demographics(livability_data):  # geopandas cannot regnoize 'demographics' but only 'properties', so move 'demo' to 'prop'
    for f in livability_data['features']:
        dem = f.pop('demographics')
        f['properties'].update(dem)
    return livability_data

# Single call to AARP without handling if the result size is larger than the 1000-block-group limit
def read_aarp_livability(swx, swy, nex, ney):
    url = f'https://geoapp.livabilityindex.byf1.io/demographicGeo?swX={swx}&swY={swy}&neX={nex}&neY={ney}&geo_type=blockgroup&simplificationLevel=0.0001'
    print(url)
    with requests.session() as session:
        response = session.get(url)
        try:
            response.raise_for_status()
        except Exception as e:
            if response.text == 'No rows returned for query.':
                return None 
            raise Exception(f'Failed to query {url} due to: {response.text}') from e
        raw_data = response.json()
        # merge the demographics fields from `raw_data` into `properties` fields such that GeoPandas could 
        # recognize and put them in the result dataframe
        merged_data = merge_properties_and_demographics(raw_data)
        # use GeoPandas to read the data, use `io.StringIO()` to convert a string to a in-memory file
        df = gpd.read_file(io.StringIO(json.dumps(merged_data)))
    return df

# %%
aa = read_aarp_livability(-74.04883861541748, 40.69866554506028, -74.01626586914062, 40.72810434130303)
aa.head()
# Out:
# https://geoapp.livabilityindex.byf1.io/demographicGeo?swX=-74.04883861541748&swY=40.69866554506028&neX=-74.01626586914062&neY=40.72810434130303&geo_type=blockgroup&simplificationLevel=0.0001
#    state_fips  total_popu  pct_africa  pct_asian  pct_hispan  pct_50plus  \
# 0          34        1931           7         11          15          31
# 1          34           0           0          0           0           0
# 2          36           0           0          0           0           0
# 3          36           0           0          0           0           0
# 4          36        1754           3         21          12           5
#
#    pct_65plus  median_inc  pct_povert  pct_disabi  ...  prox_vacant  \
# 0           9      174722           0           9  ...        0.106
# 1           0           0           0           9  ...        0.116
# 2           0       59190           0          10  ...        0.116
# 3           0           0           0          10  ...        0.116
# 4           0      139219          12          10  ...        0.263
#
#    trans_freq  trans_access  trans_walk_trip  trans_delay  trans_cost  \
# 0         0.0         0.933             0.59       32.996       11689
# 1         0.0         0.933             0.52       32.996       13820
# 2         0.0         0.933             0.48       32.996       13820
# 3         0.0         0.933             0.49       32.996       13820
# 4       739.0         0.933             5.55       32.996        7622
#
#    trans_fatal  trans_speed_lim  total_score  \
# 0        3.052            31.86    47.428571
# 1        2.658            27.27    44.571429
# 2        2.627            25.00    45.428571
# 3        2.494            26.03    41.000000
# 4        2.650            28.04    54.571429
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.09860 40.68228, -74.09636 ...
# 1  MULTIPOLYGON (((-74.06875 40.70099, -74.06722 ...
# 2  MULTIPOLYGON (((-74.04075 40.70017, -74.04008 ...
# 3  MULTIPOLYGON (((-74.03294 40.68778, -74.02628 ...
# 4  MULTIPOLYGON (((-74.01661 40.70496, -74.01551 ...
#
# [5 rows x 63 columns]

# %%
# GeoJSON(json.loads(aa.to_json()))

# %% [markdown]
# # Read shapefiles / block groups

# %% [markdown]
# ## State IDs
#
# The state id data was scaped from https://www.census.gov/cgi-bin/geo/shapefiles/index.php

# %%
state_id_filename = 'data_aarp_census/census/block_group_shapefiles/shapefile_state_ids.json'
state_ids = json.loads(Path(state_id_filename).read_text())
state_ids
# Out:
# {'01': 'Alabama',
#  '02': 'Alaska',
#  '60': 'American Samoa',
#  '04': 'Arizona',
#  '05': 'Arkansas',
#  '06': 'California',
#  '08': 'Colorado',
#  '69': 'Commonwealth of the Northern Mariana Islands',
#  '09': 'Connecticut',
#  '10': 'Delaware',
#  '11': 'District of Columbia',
#  '12': 'Florida',
#  '13': 'Georgia',
#  '66': 'Guam',
#  '15': 'Hawaii',
#  '16': 'Idaho',
#  '17': 'Illinois',
#  '18': 'Indiana',
#  '19': 'Iowa',
#  '20': 'Kansas',
#  '21': 'Kentucky',
#  '22': 'Louisiana',
#  '23': 'Maine',
#  '24': 'Maryland',
#  '25': 'Massachusetts',
#  '26': 'Michigan',
#  '27': 'Minnesota',
#  '28': 'Mississippi',
#  '29': 'Missouri',
#  '30': 'Montana',
#  '31': 'Nebraska',
#  '32': 'Nevada',
#  '33': 'New Hampshire',
#  '34': 'New Jersey',
#  '35': 'New Mexico',
#  '36': 'New York',
#  '37': 'North Carolina',
#  '38': 'North Dakota',
#  '39': 'Ohio',
#  '40': 'Oklahoma',
#  '41': 'Oregon',
#  '42': 'Pennsylvania',
#  '72': 'Puerto Rico',
#  '44': 'Rhode Island',
#  '45': 'South Carolina',
#  '46': 'South Dakota',
#  '47': 'Tennessee',
#  '48': 'Texas',
#  '49': 'Utah',
#  '50': 'Vermont',
#  '78': 'Virgin Islands of the United States',
#  '51': 'Virginia',
#  '53': 'Washington',
#  '54': 'West Virginia',
#  '55': 'Wisconsin',
#  '56': 'Wyoming'}

# %% [markdown]
# ## State-County IDs
#
# Full list of state & county ids: https://www.census.gov/prod/techdoc/cbp/cbp95/st-cnty.pdf

# %% [markdown]
# ## Read shapefiles

# %%
def read_shapefiles(sids):
    dfs = []
    for sid in sids:
        df = gpd.read_file(f'data_aarp_census/census/block_group_shapefiles/{sid}/tl_2018_{sid}_bg.shp')
        dfs.append(df)
    return pd.concat(dfs).reset_index(drop=True)

shape_df = read_shapefiles([34, 36])  # NJ and NY
shape_df
# Out:
#       STATEFP COUNTYFP TRACTCE BLKGRPCE         GEOID       NAMELSAD  MTFCC  \
# 0          34      013  017302        1  340130173021  Block Group 1  G5030
# 1          34      013  017302        2  340130173022  Block Group 2  G5030
# 2          34      013  017400        1  340130174001  Block Group 1  G5030
# 3          34      013  017400        2  340130174002  Block Group 2  G5030
# 4          34      013  017400        3  340130174003  Block Group 3  G5030
# ...       ...      ...     ...      ...           ...            ...    ...
# 21778      36      047  023100        1  360470231001  Block Group 1  G5030
# 21779      36      047  023100        3  360470231003  Block Group 3  G5030
# 21780      36      047  023200        1  360470232001  Block Group 1  G5030
# 21781      36      047  026100        5  360470261005  Block Group 5  G5030
# 21782      36      047  026900        1  360470269001  Block Group 1  G5030
#
#       FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0            S  1068288       0  +40.7959633  -074.2754595
# 1            S   375431       0  +40.7964973  -074.2826621
# 2            S  3339601    3649  +40.8171740  -074.2470590
# 3            S   360833       0  +40.8043974  -074.2535816
# 4            S  1709060   18160  +40.7992993  -074.2575472
# ...        ...      ...     ...          ...           ...
# 21778        S    39857       0  +40.6879848  -073.9612764
# 21779        S    39835       0  +40.6839002  -073.9609460
# 21780        S    56510       0  +40.6342211  -073.9839896
# 21781        S    39883       0  +40.6933351  -073.9473502
# 21782        S    39750       0  +40.6819395  -073.9421832
#
#                                                 geometry
# 0      POLYGON ((-74.28439 40.79932, -74.28271 40.802...
# 1      POLYGON ((-74.28704 40.79442, -74.28669 40.795...
# 2      POLYGON ((-74.26024 40.81086, -74.26008 40.811...
# 3      POLYGON ((-74.25795 40.80542, -74.25791 40.805...
# 4      POLYGON ((-74.26722 40.79706, -74.26713 40.797...
# ...                                                  ...
# 21778  POLYGON ((-73.96284 40.68856, -73.96093 40.688...
# 21779  POLYGON ((-73.96211 40.68489, -73.96115 40.685...
# 21780  POLYGON ((-73.98538 40.63461, -73.98480 40.635...
# 21781  POLYGON ((-73.94891 40.69391, -73.94608 40.694...
# 21782  POLYGON ((-73.94374 40.68251, -73.94091 40.682...
#
# [21783 rows x 13 columns]

# %%
# GeoJSON(json.loads(shape_df.to_json()))

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Read all NJ and NY census median rent data

# %%
unique_state_county_ids = shape_df[['STATEFP', 'COUNTYFP']].drop_duplicates().to_numpy()

# %%
census_dfs = []
for sid, cid in unique_state_county_ids:
    print(sid, cid)
    df = get_census_data('B25058_001E', sid, cid)
    census_dfs.append(df)
census_df = pd.concat(census_dfs)
# Out:
# 34 013
# 34 029
# 34 031
# 34 037
# 34 005
# 34 003
# 34 011
# 34 035
# 34 023
# 34 001
# 34 015
# 34 039
# 34 007
# 34 025
# 34 009
# 34 019
# 34 041
# 34 017
# 34 027
# 34 021
# 34 033
# 36 111
# 36 003
# 36 029
# 36 103
# 36 117
# 36 005
# 36 055
# 36 079
# 36 061
# 36 059
# 36 081
# 36 063
# 36 019
# 36 065
# 36 119
# 36 093
# 36 001
# 36 023
# 36 105
# 36 041
# 36 101
# 36 069
# 36 007
# 36 075
# 36 091
# 36 047
# 36 009
# 36 051
# 36 109
# 36 083
# 36 039
# 36 027
# 36 099
# 36 045
# 36 011
# 36 089
# 36 067
# 36 085
# 36 115
# 36 087
# 36 015
# 36 021
# 36 095
# 36 017
# 36 073
# 36 123
# 36 113
# 36 097
# 36 043
# 36 035
# 36 013
# 36 057
# 36 071
# 36 033
# 36 031
# 36 107
# 36 121
# 36 077
# 36 037
# 36 049
# 36 025
# 36 053

# %%
census_df = census_df.sort_values(['state', 'county', 'tract', 'block group']).reset_index(drop=True)

# %%
census_df['state']
# Out:
# 0        34
# 1        34
# 2        34
# 3        34
# 4        34
#          ..
# 21778    36
# 21779    36
# 21780    36
# 21781    36
# 21782    36
# Name: state, Length: 21783, dtype: object

# %%
census_df['GEOID'] = census_df.apply(lambda x:  x['state'] + x['county'] + x['tract'] + x['block group'], axis=1)
census_df
# Out:
#       B25058_001E state county   tract block group         GEOID
# 0            1042    34    001  000100           1  340010001001
# 1             833    34    001  000100           2  340010001002
# 2             894    34    001  000200           1  340010002001
# 3             991    34    001  000200           2  340010002002
# 4            1157    34    001  000200           3  340010002003
# ...           ...   ...    ...     ...         ...           ...
# 21778         689    36    123  150400           4  361231504004
# 21779         487    36    123  150500           1  361231505001
# 21780         535    36    123  150500           2  361231505002
# 21781         468    36    123  150500           3  361231505003
# 21782         674    36    123  150500           4  361231505004
#
# [21783 rows x 6 columns]

# %%
census_df.to_csv('data_aarp_census/census/medium_contract_rent_nj_ny.csv', index=False)

# %%
census_df = pd.read_csv('data_aarp_census/census/medium_contract_rent_nj_ny.csv', dtype={'state': str, 'county': str, 'tract': str, 'block group': str, 'GEOID': str})

# %%
census_df
# Out:
#        B25058_001E state county   tract block group         GEOID
# 0             1042    34    001  000100           1  340010001001
# 1              833    34    001  000100           2  340010001002
# 2              894    34    001  000200           1  340010002001
# 3              991    34    001  000200           2  340010002002
# 4             1157    34    001  000200           3  340010002003
# ...            ...   ...    ...     ...         ...           ...
# 21778          689    36    123  150400           4  361231504004
# 21779          487    36    123  150500           1  361231505001
# 21780          535    36    123  150500           2  361231505002
# 21781          468    36    123  150500           3  361231505003
# 21782          674    36    123  150500           4  361231505004
#
# [21783 rows x 6 columns]

# %%
census_df.dtypes
# Out:
# B25058_001E     int64
# state          object
# county         object
# tract          object
# block group    object
# GEOID          object
# dtype: object

# %% [markdown]
# ## Read all NJ and NY AARP livability data

# %% [markdown]
# ### Read by recusively divide the bounding box into four quadrants if exceeding the 1000-block-group limit
#
# First determine the overall bounding box

# %%
shape_df[['minx', 'miny', 'maxx', 'maxy']] = shape_df['geometry'].bounds
minx = min(shape_df['minx'])
miny = min(shape_df['miny'])
maxx = max(shape_df['maxx'])
maxy = max(shape_df['maxy'])
minx, miny, maxx, maxy
# Out:
# (-79.76259, 38.788657, -71.777491, 45.015865)

# %%
def get_aarp_livability_recursive(minx, miny, maxx, maxy):
    df = read_aarp_livability(minx, miny, maxx, maxy)
#     print(minx, miny, maxx, maxy, len(df) if df is not None else None)
    if df is None or len(df) < 1000:  # AARP limits to return only 1000 block groups
        return df
    midx = (minx + maxx) * .5
    midy = (miny + maxy) * .5
    lower_left_df = get_aarp_livability_bound(minx, miny, midx, midy)
    lower_right_df = get_aarp_livability_bound(midx, miny, maxx, midy)
    upper_right_df = get_aarp_livability_bound(midx, midy, maxx, maxy)
    upper_left_df = get_aarp_livability_bound(minx, midy, midx, maxy)
    sub_dfs = [lower_left_df, lower_right_df, upper_right_df, upper_left_df]
    df = pd.concat([sub_df for sub_df in sub_dfs if sub_df is not None])
    df = df.reset_index(drop=True).drop_duplicates()
    return df

aarp_df = get_aarp_livability_recursive(minx, miny, maxx, maxy)
len(aarp_df)

# %% [raw]
# aarp_df.to_pickle('data_aarp_census/aarp/nj_ny_raw.pickle')

# %%
aarp_df = pd.read_pickle('data_aarp_census/aarp/nj_ny_raw.pickle')
aarp_df.head()
# Out:
#    state_fips  total_popu  pct_africa  pct_asian  pct_hispan  pct_50plus  \
# 0          24         761           1          2           0          64
# 1          24        1662           2          0           2          43
# 2          24        1109           1          0           1          34
# 3          24        1058           1          0           5          28
# 4          24         945           0          0           0          42
#
#    pct_65plus  median_inc  pct_povert  pct_disabi  ...  prox_vacant  \
# 0          27       50547           2          18  ...        0.483
# 1          21       41602          13          18  ...        0.214
# 2          18       55313           8          18  ...        0.236
# 3          12       47330          10          18  ...        0.283
# 4          21       31875          30          18  ...        0.025
#
#    trans_freq  trans_access  trans_walk_trip  trans_delay  trans_cost  \
# 0         0.0           1.0             0.46          0.0       14441
# 1         0.0           1.0             0.48          0.0       14371
# 2         0.0           1.0             0.47          0.0       14069
# 3         0.0           1.0             0.46          0.0       14046
# 4         0.0           1.0             0.49          0.0       13495
#
#    trans_fatal  trans_speed_lim  total_score  \
# 0       65.023            37.09    37.714286
# 1       23.263            37.62    46.714286
# 2       50.447            27.99    46.142857
# 3       10.469            27.49    46.000000
# 4        7.504            39.79    45.142857
#
#                                             geometry
# 0  MULTIPOLYGON (((-78.49626 39.60436, -78.49496 ...
# 1  MULTIPOLYGON (((-78.66648 39.64913, -78.66557 ...
# 2  MULTIPOLYGON (((-78.65719 39.60715, -78.65681 ...
# 3  MULTIPOLYGON (((-78.73159 39.58253, -78.73092 ...
# 4  MULTIPOLYGON (((-78.71766 39.70091, -78.71264 ...
#
# [5 rows x 63 columns]

# %% [markdown]
# ### Filter by NJ and NY

# %%
aarp_df =  aarp_df[np.isin(aarp_df.state_fips, [34, 36])]
len(aarp_df)
# Out:
# 21783

# %% [raw]
# tt =json.loads(aarp_df.to_json())
# GeoJSON(tt)

# %% [markdown]
# ### Build GEOID to internal point mapping

# %%
GEOID_TO_INTPS = {}
for i, geoid, lat, lon in shape_df[['GEOID', 'INTPTLAT', 'INTPTLON']].itertuples():
    GEOID_TO_INTPS[geoid] = Point(float(lon), float(lat))

# %% [markdown]
# ### Use GEOID to internal point mapping to mark the AARP block group ploy with the right GEOID

# %%
find_count = 0

def find_block_group(polygon):
    global find_count
    if find_count % 100 == 0:
        print(f'identified {find_count} block groups')
    find_count += 1
    for geoid, intp in GEOID_TO_INTPS.items():
        if polygon.contains(intp):
            return geoid
    return None

aarp_df['GEOID'] = aarp_df['geometry'].apply(lambda x: find_block_group(x))
# Out:
# identified 0 block groups
# identified 100 block groups
# identified 200 block groups
# identified 300 block groups
# identified 400 block groups
# identified 500 block groups
# identified 600 block groups
# identified 700 block groups
# identified 800 block groups
# identified 900 block groups
# identified 1000 block groups
# identified 1100 block groups
# identified 1200 block groups
# identified 1300 block groups
# identified 1400 block groups
# identified 1500 block groups
# identified 1600 block groups
# identified 1700 block groups
# identified 1800 block groups
# identified 1900 block groups
# identified 2000 block groups
# identified 2100 block groups
# identified 2200 block groups
# identified 2300 block groups
# identified 2400 block groups
# identified 2500 block groups
# identified 2600 block groups
# identified 2700 block groups
# identified 2800 block groups
# identified 2900 block groups
# identified 3000 block groups
# identified 3100 block groups
# identified 3200 block groups
# identified 3300 block groups
# identified 3400 block groups
# identified 3500 block groups
# identified 3600 block groups
# identified 3700 block groups
# identified 3800 block groups
# identified 3900 block groups
# identified 4000 block groups
# identified 4100 block groups
# identified 4200 block groups
# identified 4300 block groups
# identified 4400 block groups
# identified 4500 block groups
# identified 4600 block groups
# identified 4700 block groups
# identified 4800 block groups
# identified 4900 block groups
# identified 5000 block groups
# identified 5100 block groups
# identified 5200 block groups
# identified 5300 block groups
# identified 5400 block groups
# identified 5500 block groups
# identified 5600 block groups
# identified 5700 block groups
# identified 5800 block groups
# identified 5900 block groups
# identified 6000 block groups
# identified 6100 block groups
# identified 6200 block groups
# identified 6300 block groups
# identified 6400 block groups
# identified 6500 block groups
# identified 6600 block groups
# identified 6700 block groups
# identified 6800 block groups
# identified 6900 block groups
# identified 7000 block groups
# identified 7100 block groups
# identified 7200 block groups
# identified 7300 block groups
# identified 7400 block groups
# identified 7500 block groups
# identified 7600 block groups
# identified 7700 block groups
# identified 7800 block groups
# identified 7900 block groups
# identified 8000 block groups
# identified 8100 block groups
# identified 8200 block groups
# identified 8300 block groups
# identified 8400 block groups
# identified 8500 block groups
# identified 8600 block groups
# identified 8700 block groups
# identified 8800 block groups
# identified 8900 block groups
# identified 9000 block groups
# identified 9100 block groups
# identified 9200 block groups
# identified 9300 block groups
# identified 9400 block groups
# identified 9500 block groups
# identified 9600 block groups
# identified 9700 block groups
# identified 9800 block groups
# identified 9900 block groups
# identified 10000 block groups
# identified 10100 block groups
# identified 10200 block groups
# identified 10300 block groups
# identified 10400 block groups
# identified 10500 block groups
# identified 10600 block groups
# identified 10700 block groups
# identified 10800 block groups
# identified 10900 block groups
# identified 11000 block groups
# identified 11100 block groups
# identified 11200 block groups
# identified 11300 block groups
# identified 11400 block groups
# identified 11500 block groups
# identified 11600 block groups
# identified 11700 block groups
# identified 11800 block groups
# identified 11900 block groups
# identified 12000 block groups
# identified 12100 block groups
# identified 12200 block groups
# identified 12300 block groups
# identified 12400 block groups
# identified 12500 block groups
# identified 12600 block groups
# identified 12700 block groups
# identified 12800 block groups
# identified 12900 block groups
# identified 13000 block groups
# identified 13100 block groups
# identified 13200 block groups
# identified 13300 block groups
# identified 13400 block groups
# identified 13500 block groups
# identified 13600 block groups
# identified 13700 block groups
# identified 13800 block groups
# identified 13900 block groups
# identified 14000 block groups
# identified 14100 block groups
# identified 14200 block groups
# identified 14300 block groups
# identified 14400 block groups
# identified 14500 block groups
# identified 14600 block groups
# identified 14700 block groups
# identified 14800 block groups
# identified 14900 block groups
# identified 15000 block groups
# identified 15100 block groups
# identified 15200 block groups
# identified 15300 block groups
# identified 15400 block groups
# identified 15500 block groups
# identified 15600 block groups
# identified 15700 block groups
# identified 15800 block groups
# identified 15900 block groups
# identified 16000 block groups
# identified 16100 block groups
# identified 16200 block groups
# identified 16300 block groups
# identified 16400 block groups
# identified 16500 block groups
# identified 16600 block groups
# identified 16700 block groups
# identified 16800 block groups
# identified 16900 block groups
# identified 17000 block groups
# identified 17100 block groups
# identified 17200 block groups
# identified 17300 block groups
# identified 17400 block groups
# identified 17500 block groups
# identified 17600 block groups
# identified 17700 block groups
# identified 17800 block groups
# identified 17900 block groups
# identified 18000 block groups
# identified 18100 block groups
# identified 18200 block groups
# identified 18300 block groups
# identified 18400 block groups
# identified 18500 block groups
# identified 18600 block groups
# identified 18700 block groups
# identified 18800 block groups
# identified 18900 block groups
# identified 19000 block groups
# identified 19100 block groups
# identified 19200 block groups
# identified 19300 block groups
# identified 19400 block groups
# identified 19500 block groups
# identified 19600 block groups
# identified 19700 block groups
# identified 19800 block groups
# identified 19900 block groups
# identified 20000 block groups
# identified 20100 block groups
# identified 20200 block groups
# identified 20300 block groups
# identified 20400 block groups
# identified 20500 block groups
# identified 20600 block groups
# identified 20700 block groups
# identified 20800 block groups
# identified 20900 block groups
# identified 21000 block groups
# identified 21100 block groups
# identified 21200 block groups
# identified 21300 block groups
# identified 21400 block groups
# identified 21500 block groups
# identified 21600 block groups
# identified 21700 block groups

# %%
aarp_df.to_pickle('data_aarp_census/aarp/nj_ny_geoid.pickle')

# %% [markdown]
# ### Merge AARP livability dataset with Census median rent dataset by GEOID

# %%
all_df = aarp_df.merge(census_df, how='outer', on='GEOID')

# %%
all_df = all_df.drop(columns=['geometry', 'state_fips'])
all_df
# Out:
#        total_popu  pct_africa  pct_asian  pct_hispan  pct_50plus  pct_65plus  \
# 0          1112.0         8.0        0.0        21.0        31.0        11.0
# 1          1203.0         3.0        0.0         2.0        37.0        11.0
# 2          2303.0         3.0        1.0        16.0        42.0        13.0
# 3          1534.0         0.0        0.0         1.0        60.0        41.0
# 4          1295.0         2.0        0.0         4.0        34.0        13.0
# ...           ...         ...        ...         ...         ...         ...
# 21787         NaN         NaN        NaN         NaN         NaN         NaN
# 21788         NaN         NaN        NaN         NaN         NaN         NaN
# 21789         NaN         NaN        NaN         NaN         NaN         NaN
# 21790         NaN         NaN        NaN         NaN         NaN         NaN
# 21791         NaN         NaN        NaN         NaN         NaN         NaN
#
#        median_inc  pct_povert  pct_disabi  pct_novehi  ...  trans_cost  \
# 0         64250.0         0.0        12.0         5.0  ...     15034.0
# 1         69375.0         4.0        12.0         1.0  ...     15223.0
# 2         72870.0        14.0        12.0         3.0  ...     14611.0
# 3         39196.0        10.0        12.0         6.0  ...     14096.0
# 4         75750.0         2.0        12.0         6.0  ...     15039.0
# ...           ...         ...         ...         ...  ...         ...
# 21787         NaN         NaN         NaN         NaN  ...         NaN
# 21788         NaN         NaN         NaN         NaN  ...         NaN
# 21789         NaN         NaN         NaN         NaN  ...         NaN
# 21790         NaN         NaN         NaN         NaN  ...         NaN
# 21791         NaN         NaN         NaN         NaN  ...         NaN
#
#        trans_fatal  trans_speed_lim  total_score         GEOID  B25058_001E  \
# 0           19.252            33.40    43.857143  340010107001 -666666666.0
# 1           24.897            41.57    44.714286  340010112011        917.0
# 2            8.331            33.17    47.000000  340010112021       1201.0
# 3            8.375            29.43    46.000000  340010112022       1417.0
# 4           23.952            28.58    44.714286  340010112023 -666666666.0
# ...            ...              ...          ...           ...          ...
# 21787          NaN              NaN          NaN  340312460036 -666666666.0
# 21788          NaN              NaN          NaN  360470702031 -666666666.0
# 21789          NaN              NaN          NaN  360510302021        613.0
# 21790          NaN              NaN          NaN  360811008012       1690.0
# 21791          NaN              NaN          NaN  361190115003       2009.0
#
#        state  county   tract  block group
# 0         34     001  010700            1
# 1         34     001  011201            1
# 2         34     001  011202            1
# 3         34     001  011202            2
# 4         34     001  011202            3
# ...      ...     ...     ...          ...
# 21787     34     031  246003            6
# 21788     36     047  070203            1
# 21789     36     051  030202            1
# 21790     36     081  100801            2
# 21791     36     119  011500            3
#
# [21792 rows x 67 columns]

# %%
all_df.to_pickle('data_aarp_census/nj_ny_merged_with_census.pickle')

# %%
all_df[(all_df['B25058_001E'] > 0) & (all_df['total_score'] > 0)]
# Out:
#        total_popu  pct_africa  pct_asian  pct_hispan  pct_50plus  pct_65plus  \
# 1          1203.0         3.0        0.0         2.0        37.0        11.0
# 2          2303.0         3.0        1.0        16.0        42.0        13.0
# 3          1534.0         0.0        0.0         1.0        60.0        41.0
# 5          2466.0        33.0        0.0        22.0        30.0        19.0
# 6          1278.0        11.0        2.0        47.0        23.0         4.0
# ...           ...         ...        ...         ...         ...         ...
# 21778      1645.0         0.0        0.0         6.0        32.0        20.0
# 21779       863.0         0.0        1.0         2.0        30.0         8.0
# 21780      1586.0         1.0        0.0         2.0        32.0        11.0
# 21781       980.0         3.0        0.0         1.0        37.0        11.0
# 21782       407.0         4.0        0.0         0.0        31.0        14.0
#
#        median_inc  pct_povert  pct_disabi  pct_novehi  ...  trans_cost  \
# 1         69375.0         4.0        12.0         1.0  ...     15223.0
# 2         72870.0        14.0        12.0         3.0  ...     14611.0
# 3         39196.0        10.0        12.0         6.0  ...     14096.0
# 5         44318.0        23.0        12.0         6.0  ...     15141.0
# 6         69938.0         1.0        12.0         0.0  ...     14081.0
# ...           ...         ...         ...         ...  ...         ...
# 21778     49185.0         9.0        13.0         4.0  ...     15705.0
# 21779     38333.0        20.0        13.0         0.0  ...     15214.0
# 21780     49583.0        14.0        13.0         2.0  ...     15333.0
# 21781     32813.0        36.0        13.0         0.0  ...     14359.0
# 21782     39429.0        15.0        13.0         8.0  ...     12506.0
#
#        trans_fatal  trans_speed_lim  total_score         GEOID  B25058_001E  \
# 1           24.897            41.57    44.714286  340010112011        917.0
# 2            8.331            33.17    47.000000  340010112021       1201.0
# 3            8.375            29.43    46.000000  340010112022       1417.0
# 5           16.489            30.35    45.571429  340010112024        843.0
# 6            9.852            28.31    47.857143  340010113001       1151.0
# ...            ...              ...          ...           ...          ...
# 21778       14.666            31.60    42.428571  360750203022        653.0
# 21779       15.275            32.45    46.428571  360750205003        475.0
# 21780       16.890            29.71    44.428571  360750215011        543.0
# 21781        3.355            25.00    40.571429  360750215021        565.0
# 21782        3.503            25.31    53.142857  360750216054        527.0
#
#        state  county   tract  block group
# 1         34     001  011201            1
# 2         34     001  011202            1
# 3         34     001  011202            2
# 5         34     001  011202            4
# 6         34     001  011300            1
# ...      ...     ...     ...          ...
# 21778     36     075  020302            2
# 21779     36     075  020500            3
# 21780     36     075  021501            1
# 21781     36     075  021502            1
# 21782     36     075  021605            4
#
# [16364 rows x 67 columns]

# %% [markdown]
# # Appendix

# %% [raw]
# # Draw bounding box
# bound_polygon = {'id': '9999',
#  'type': 'Feature',
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[
#       [minx, miny],
#       [maxx, miny],
#       [maxx, maxy],
#       [minx, maxy],
#   ]]]}}
#
# tt['features'].append(bound_polygon)
# len(tt['features'])
#
# GeoJSON(tt)

# %% [markdown]
# #### Read by county --- NOT USED as it does not handle the 1000-block-group limit

# %% [raw]
# county_bounds_df = shape_df[['STATEFP', 'COUNTYFP', 'minx', 'miny', 'maxx', 'maxy']].groupby(['STATEFP', 'COUNTYFP']).agg({'minx': 'min', 'miny': 'min', 'maxx': 'max', 'maxy': 'max'})
# county_bounds_df

# %% [raw]
# list(county_bounds_df.itertuples())[:3]

# %% [raw]
# def get_aarp_livability_by_county(minx, miny, maxx, maxy):
#     return read_aarp_livability(minx, miny, maxx, maxy)
#
# dfs = []
# for (sid, cid), minx, miny, maxx, maxy in list(county_bounds_df.itertuples())[:3]:
#     df = get_aarp_livability_by_county(minx, miny, maxx, maxy)
#     print(sid, cid, df.shape)
#     dfs.append(df)
# livability_df = pd.concat(dfs).reset_index()
